# %%
import pandas as pd
# Out:
# Les cellules en cours d’exécution avec snowflake_tel_insights (Python 3.12.11) nécessitent le package ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Créer un environnement Python</a> avec les packages requis.

# %%
df = pd.read_csv("/home/antoine/workspace/snowflake_dbt_telephony_insights/data/RAW_MT20/MT20_ORANGE.csv", sep=';', dtype=str, on_bad_lines='skip', encoding='latin-1')

df.head(10)
# Out:
# Les cellules en cours d’exécution avec snowflake_tel_insights (Python 3.12.11) nécessitent le package ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Créer un environnement Python</a> avec les packages requis.
